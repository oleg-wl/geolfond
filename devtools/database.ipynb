# %%
import pandas as pd
import numpy as np

# %%
df_copy = pd.read_excel(io='../data.xlsx')
df_copy = df_copy.drop(df_copy.columns[0], axis=1)

# %%
df = df_copy.copy()
len(df)
# Out:
# 16092

# %%
df[df[['num']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [num, date, state, type, name, INN, owner, prew_owner, Last, Year, prev_lic, prev_date, forw_lic, forw_date, N, E]
# Index: []

# %%
#Таблица владельцев лицензии - компания + ИНН
owners = df[['owner','INN']].drop_duplicates(keep='first').dropna()
owners['id'] = range(0, len(owners))
#owners.loc[owners['owner'].isna(), 'id'] = np.nan #удаление задвоенных дубликатов
print(owners[owners['INN'] == 8901001325])
#присоединение столбца ID
test = pd.merge(df, owners[['owner', 'id']], left_on=['owner'], right_on=['owner'], how='left').rename(columns={'id':'owner_id'})
#.drop(columns=['owner'])
#df 
test[['num','owner','INN']][test.duplicated(subset='num',keep=False)]

x = test['owner'][test.duplicated(subset='num',keep='first')].tolist()
owners[owners['owner'].isin(set(x))].drop_duplicates(subset='INN', keep='first').sort_values(by='owner').to_csv('inn_duplicates.csv', sep=',')
# Out:
#                             owner           INN   id
# 6424  РОСНЕФТЬ - ЯМАЛНЕФТЕПРОДУКТ  8.901001e+09  968

# %%
test = pd.merge(df['prew_owner'], owners[['owner', 'id']], left_on=df['prew_owner'], right_on=owners['owner'], how='left', indicator=True, )
#test[test['_merge'] == 'both']
#test[test['key_0'].notna()]
#test['_merge'].values
#test[(test['id'] != 9) & (test['prew_owner'].isna())]
test
# Out:
#                                                    key_0  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17886                               ЗАО НафтаСиб-Иркутск
# 17887  Открытое акционерное общество "Якутская топлив...
# 17888            ООО "Газодобывающая компания Ленск-газ"
# 17889  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СЮЛЬ...
# 17890  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МИРН...
#
#                                               prew_owner  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
df = pd.merge(df, owners[['owner', 'id']], left_on=df['prew_owner'], right_on=owners['owner'], how='left') #.rename(columns={'id':'prew_owner_id'}).drop(columns=['prew_owner'])
len(df)
# Out:
# 19667

# %%
df
# Out:
#               num       date                     state type  \
# 0      АБН00011НР 1993-06-08        Республика Хакасия  УВС
# 1      АБН00220НП 1997-10-07        Республика Хакасия  УВС
# 2      КРР00680НП 1998-04-07         Красноярский край  УВС
# 3      КРР00926НП 2000-04-17         Красноярский край  УВС
# 4      КРР01022НП 2000-10-06         Красноярский край  УВС
# ...           ...        ...                       ...  ...
# 17886  ЯКУ15625НР 2013-11-01  Республика Саха (Якутия)  УВС
# 17887  ЯКУ15815НР 2014-12-03  Республика Саха (Якутия)  УВС
# 17888  ЯКУ15826НР 2014-12-17  Республика Саха (Якутия)  УВС
# 17889  ЯКУ16004НР 2016-02-29  Республика Саха (Якутия)  УВС
# 17890  ЯКУ16436НР 2018-01-22  Республика Саха (Якутия)  УВС
#
#                                                     name           INN  \
# 0                               Новомихайловская площадь  1.904001e+09
# 1                              Ново-Михайловская площадь  2.466013e+09
# ...

# %%
place = df[['name']].drop_duplicates(keep='first')
place['id'] = range(0, len(place))

# %%
state = df['state'].drop_duplicates(keep='first')
state['id'] = range(0, len(state))

# %%
df
# Out:
#               num       date                     state type  \
# 0      АБН00011НР 1993-06-08        Республика Хакасия  УВС
# 1      АБН00220НП 1997-10-07        Республика Хакасия  УВС
# 2      КРР00680НП 1998-04-07         Красноярский край  УВС
# 3      КРР00926НП 2000-04-17         Красноярский край  УВС
# 4      КРР01022НП 2000-10-06         Красноярский край  УВС
# ...           ...        ...                       ...  ...
# 16998  ЯКУ15625НР 2013-11-01  Республика Саха (Якутия)  УВС
# 16999  ЯКУ15815НР 2014-12-03  Республика Саха (Якутия)  УВС
# 17000  ЯКУ15826НР 2014-12-17  Республика Саха (Якутия)  УВС
# 17001  ЯКУ16004НР 2016-02-29  Республика Саха (Якутия)  УВС
# 17002  ЯКУ16436НР 2018-01-22  Республика Саха (Якутия)  УВС
#
#                                                     name           INN  \
# 0                               Новомихайловская площадь  1.904001e+09
# 1                              Ново-Михайловская площадь  2.466013e+09
# ...

# %%
owners
# Out:
#                                                    owner           INN    id
# 0                                 АООТ Хакаснефтегазпром  1.904001e+09     0
# 1                                     ОАО Енисейнефтегаз  2.466013e+09     1
# 2      Федеральное государственное автономное учрежде...  7.018007e+09     2
# 3      ООО Технологический инкубатор Томского политех...  7.017109e+09     3
# 4                                            ООО Сохочул  7.017216e+09     4
# ...                                                  ...           ...   ...
# 16059  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЕНА...  3.849028e+09  2943
# 16065  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МИРН...  1.435282e+09  2944
# 16066  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КЭДЭ...  1.435284e+09  2945
# 16075  Общество с ограниченной ответственностью "Мурб...  7.702388e+09  2946
# 16086  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "САХА...  1.435323e+09  2947
#
# [2948 rows x 3 columns]
