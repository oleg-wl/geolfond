# %%
from Parser import client

# %%
from sys import getsizeof

# %%
df = client.get_data_from_reestr(filter='oil')[0]

# %%
getsizeof(df)
# Out:
# 464

# %%
l = []

for i in range(len(df['num'])):
    d = {}
    for key in df:
        d[key] = df[key][i]
    l.append(d)

# %%
cols = [x for x in df.keys()]
vals = [x for x in df.values()]

# %%
lst = []
for i in range(len(vals[0])):
    d = {}
    for n, key in enumerate(cols):
        d[key] = vals[n][i]
    lst.append(d)

# %%
d3 = [{key:vals[n][i] for n, key in enumerate(cols)} for i in  range(len(vals[0])) ]

# %%
import pandas as pd

# %%
pd.DataFrame(d3)
# Out:
#                                        link  ...                                          link_alsn
# 0      https://rfgf.ru/ReestrLicPage/429733  ...  https://asln.rosnedra.gov.ru/?elid=254&id_lc=4...
# 1      https://rfgf.ru/ReestrLicPage/429730  ...  https://asln.rosnedra.gov.ru/?elid=254&id_lc=4...
# 2      https://rfgf.ru/ReestrLicPage/429653  ...  https://asln.rosnedra.gov.ru/?elid=254&id_lc=4...
# 3      https://rfgf.ru/ReestrLicPage/429421  ...  https://asln.rosnedra.gov.ru/?elid=254&id_lc=4...
# 4      https://rfgf.ru/ReestrLicPage/429074  ...  https://asln.rosnedra.gov.ru/?elid=254&id_lc=4...
# ...                                     ...  ...                                                ...
# 16126  https://rfgf.ru/ReestrLicPage/215309  ...  https://asln.rosnedra.gov.ru/?asln&auth=aesia&...
# 16127  https://rfgf.ru/ReestrLicPage/215310  ...  https://asln.rosnedra.gov.ru/?asln&auth=aesia&...
# 16128  https://rfgf.ru/ReestrLicPage/211135  ...  https://asln.rosnedra.gov.ru/?asln&auth=aesia&...
# 16129  https://rfgf.ru/ReestrLicPage/215552  ...  https://asln.rosnedra.gov.ru/?asln&auth=aesia&...
# 16130  https://rfgf.ru/ReestrLicPage/215280  ...  https://asln.rosnedra.gov.ru/?asln&auth=aesia&...
#
# [16131 rows x 21 columns]

# %%
getsizeof(d3)
# Out:
# 136632
